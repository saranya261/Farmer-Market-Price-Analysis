# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("tomato_jan_2024.csv", header=None, names=["date", "arrivals", "variety", "min_price", "max_price", "modal_price"])
df.head(10)
# Out:
#                                                 date  \
# 0  Date Wise Prices for Specified Commodity on Ja...
# 1         Commodity : Tomato, State : Andhra Pradesh
# 2                                       Arrival Date
# 3                        Market Name : Kalikiri APMC
# 4                                         01/01/2024
# 5                                         02/01/2024
# 6                                         03/01/2024
# 7                                         04/01/2024
# 8                                         05/01/2024
# 9                                         07/01/2024
#
#                    arrivals  variety                    min_price  \
# 0                       NaN      NaN                          NaN
# 1                       NaN      NaN                          NaN
# 2  Arrivals (Metric Tonnes)  Variety  Minimum Price (Rs./Quintal)
# 3                       NaN      NaN                          NaN
# ...

# %%
import pandas as pd

df = pd.read_csv("tomato_jan_2024.csv", header=None, names=["date", "arrivals", "variety", "min_price", "max_price", "modal_price"])

df["date"] = pd.to_datetime(df["date"], dayfirst=True, errors="coerce")

df["month"] = df["date"].dt.month

df = df.dropna(subset=["date"])

print(df.shape)
df.head()
# Out:
# (693, 7)
# C:\Users\saran\AppData\Local\Temp\ipykernel_17724\417150674.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["date"] = pd.to_datetime(df["date"], dayfirst=True, errors="coerce")
#         date arrivals variety min_price max_price modal_price  month
# 4 2024-01-01      9.4   Local    1000.0    2000.0      1500.0    1.0
# 5 2024-01-02      7.0   Local    1000.0    2300.0      1700.0    1.0
# 6 2024-01-03      8.3   Local    1200.0    2660.0      2000.0    1.0
# 7 2024-01-04      8.2   Local     900.0    2000.0      1600.0    1.0
# 8 2024-01-05      7.0   Local    1000.0    2300.0      1700.0    1.0

# %%
df["modal_price"] = pd.to_numeric(df["modal_price"], errors="coerce")

monthly_avg = df.groupby("month")["modal_price"].mean()
print(monthly_avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\saran\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\saran\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\saran\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
